# %%
from models import Synthesizer

tts = Synthesizer(
    checkpoint_path="models/chhattisgarhi_vits.pth", 
    config_path="configs/config.json"
)

tts.speak("जम्मू कश्मीर म पर्यटन उद्योग ला बढ़ावा देना उहाँ के अर्थबेवस्था ला सुचारू रूप ले चलाय बर जरुरी हे")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from models import Synthesizer
#       3 tts = Synthesizer(
#       4     checkpoint_path="models/chhattisgarhi_vits.pth",
#       5     config_path="configs/config.json"
#       6 )
#       8 tts.speak("जम्मू कश्मीर म पर्यटन उद्योग ला बढ़ावा देना उहाँ के अर्थबेवस्था ला सुचारू रूप ले चलाय बर जरुरी हे")
#
# ModuleNotFoundError: No module named 'models'

# %%
import torch
from TTS.utils.synthesizer import Synthesizer

MODEL = "Female/best_model.pth"
CONFIG = "Female/config.json"

device = torch.cuda.is_available()

tts = Synthesizer(
    tts_checkpoint=MODEL,
    tts_config_path=CONFIG,
    use_cuda=device
)

text = "जम्मू कश्मीर म पर्यटन उद्योग ला बढ़ावा देना उहाँ के अर्थबेवस्था ला सुचारू रूप ले चलाय बर जरुरी हे"

wav = tts.tts(text=text, speed=12)

tts.tts_model.length_scale = .2

tts.save_wav(
    wav=wav,
    path="outputslow.wav"
)

print("Audio generated:", "outputslow.wav")
# Out:
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Text splitted to sentences.
# ['जम्मू कश्मीर म पर्यटन उद्योग ला बढ़ावा देना उहाँ के अर्थबेवस्था ला सुचारू रूप ले चलाय बर जरुरी हे']
# ...

# %%
import torch                                                                                                                        
from TTS.utils.synthesizer import Synthesizer                                                                                       
                                                                                                                                    
MODEL = "Female/best_model.pth"                                                                                                     
CONFIG = "Female/config.json"                                                                                                       
                                                                                                                                    
device = torch.cuda.is_available()                                                                                                  
                                                                                                                                    
tts = Synthesizer(                                                                                                                  
    tts_checkpoint=MODEL,                                                                                                           
    tts_config_path=CONFIG,                                                                                                         
    use_cuda=device                                                                                                                 
)                                                                                                                                   
                                                                                                                                    
text = "जम्मू कश्मीर म पर्यटन उद्योग ला बढ़ावा देना उहाँ के अर्थबेवस्था ला सुचारू रूप ले चलाय बर जरुरी हे"                                                              
                                                                                                                                    
# 1. Set the speed before generating the audio. 
# Use a number > 1.0 to make it slower (e.g., 2.0 is half speed)
tts.tts_model.length_scale = 1.25 

# 2. Generate the audio without the broken speed parameter
wav = tts.tts(text=text)

# 3. Save the result
tts.save_wav(
    wav=wav,
    path="outputslow.wav"
)

print("Audio generated:", "outputslow.wav")
# Out:
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Text splitted to sentences.
# ['जम्मू कश्मीर म पर्यटन उद्योग ला बढ़ावा देना उहाँ के अर्थबेवस्था ला सुचारू रूप ले चलाय बर जरुरी हे']
# ...
